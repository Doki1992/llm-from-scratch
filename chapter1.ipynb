# %% [markdown]
# #### Notes of the first chapter of the book build and llm from scratch
# hope this works guys!
#
# llms are neural networks trained in a vast amount of data
# We have the following part of the tranformer architecture:
# - BERT (encoder) Uses mask language modeling, eg this ________ a day  great to code
# - GPT (decoder) Uses casual language modeling, eg this is a great day to ______
